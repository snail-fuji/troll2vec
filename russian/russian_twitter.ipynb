# %%
import pandas as pd

# %%
messages= []
file = open("twitter_dataset.csv")

# %%
rus = pd.read_csv("/home/noomkcalb/Документы/social_weekend/russian/kartaslov/dataset/open_semantics/semantics.csv", sep=";")

# %%
rus
# Out:
#              term                       slice          answerA  probaA  \
# 0             аба     ATTR:INORGANIC:WEARABLE         WEARABLE  0.9993
# 1             аба     ATTR:PHYSICAL:CONTAINER  NOT_A_CONTAINER  0.9999
# 2             аба     ATTR:PHYSICAL:PHY_STATE           FABRIC  0.7206
# 3             аба         ATTR:PHYSICAL:PLACE      NOT_A_PLACE  0.9993
# 4             аба                      ENTITY         PHYSICAL  0.9998
# 5             аба     PHYSICAL:INORGANIC:ROLE            THING  0.9943
# 6             аба               PHYSICAL:ROLE        INORGANIC  0.9987
# 7          абажур     ATTR:INORGANIC:WEARABLE         WEARABLE  0.9989
# 8          абажур     ATTR:PHYSICAL:CONTAINER  NOT_A_CONTAINER  0.8726
# 9          абажур     ATTR:PHYSICAL:PHY_STATE           FABRIC  0.9938
# 10         абажур         ATTR:PHYSICAL:PLACE      NOT_A_PLACE  1.0000
# 11         абажур                      ENTITY         PHYSICAL  1.0000
# ...
